# %% [markdown]
# # toy-tabular demo
# This notebook loads the flywheel artifact and shows the model works — an intentionally trivial prediction task that proves the autonomous loop end-to-end.

# %%
import joblib

bundle = joblib.load('../artifacts/model.joblib')
clf, Xte, yte = bundle['model'], bundle['Xte'], bundle['yte']
print(f"test accuracy: {clf.score(Xte, yte):.4f}")
assert clf.score(Xte, yte) >= 0.85
print("gate f1 >= 0.85: pass")
# Out:
# test accuracy: 0.9561
# gate f1 >= 0.85: pass
